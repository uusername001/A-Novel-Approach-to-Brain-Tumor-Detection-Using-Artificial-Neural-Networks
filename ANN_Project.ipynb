# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.3)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/masoudnickparvar/brain-tumor-mri-dataset?dataset_version_number=1...
# 100%|██████████| 149M/149M [00:07<00:00, 20.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
dataset_path = "/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1"

# Define the training and testing directories
train_dir = os.path.join(dataset_path, "/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Training")
test_dir = os.path.join(dataset_path, "/root/.cache/kagglehub/datasets/masoudnickparvar/brain-tumor-mri-dataset/versions/1/Testing")

# Define the categories
categories = ["glioma", "meningioma", "notumor", "pituitary"]
train_data = []
for category in categories:
    folder_path = os.path.join(train_dir, category)
    images = os.listdir(folder_path)
    count = len(images)
    train_data.append(pd.DataFrame({"Image": images, "Category": [category] * count, "Count": [count] * count}))

train_df = pd.concat(train_data, ignore_index=True)

# Visualize the distribution of tumor types in the training dataset
plt.figure(figsize=(8, 6))
sns.barplot(data=train_df, x="Category", y="Count")
plt.title("Distribution of Tumor Types")
plt.xlabel("Tumor Type")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(12, 8))
for i, category in enumerate(categories):
    folder_path = os.path.join(train_dir, category)
    image_path = os.path.join(folder_path, os.listdir(folder_path)[0])
    img = plt.imread(image_path)
    plt.subplot(2, 2, i+1)
    plt.imshow(img)
    plt.title(category)
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
# Set the image size
image_size = (150, 150)

# Set the batch size for training
batch_size = 32

# Set the number of epochs for training
epochs = 50

# %%
# Data augmentation and preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode="nearest"
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical"
)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation="relu", input_shape=(image_size[0], image_size[1], 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation="relu"),
    Dropout(0.5),
    Dense(len(categories), activation="softmax")
])

# Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=test_generator,
    validation_steps=test_generator.samples // batch_size
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 53s 252ms/step - accuracy: 0.4701 - loss: 1.1214 - val_accuracy: 0.6859 - val_loss: 0.8468
# Epoch 2/50
#   1/178 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.6562 - loss: 0.9829
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6562 - loss: 0.9829 - val_accuracy: 0.7097 - val_loss: 0.8678
# Epoch 3/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 216ms/step - accuracy: 0.6935 - loss: 0.7643 - val_accuracy: 0.5164 - val_loss: 1.6388
# Epoch 4/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7500 - loss: 0.6007 - val_accuracy: 0.4516 - val_loss: 1.3401
# Epoch 5/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 214ms/step - accuracy: 0.7412 - loss: 0.6408 - val_accuracy: 0.6906 - val_loss: 0.7339
# Epoch 6/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7500 - loss: 0.5448 - val_accuracy: 0.9032 - val_loss: 0.5766
# Epoch 7/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 80s 224ms/step - accuracy: 0.7848 - loss: 0.5701 - val_accuracy: 0.7578 - val_loss: 0.6859
# Epoch 8/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - accuracy: 0.8125 - loss: 0.5684 - val_accuracy: 1.0000 - val_loss: 0.1740
# Epoch 9/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 80s 216ms/step - accuracy: 0.8002 - loss: 0.4998 - val_accuracy: 0.7203 - val_loss: 0.7149
# Epoch 10/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 233us/step - accuracy: 0.7812 - loss: 0.3514 - val_accuracy: 0.8387 - val_loss: 0.4425
# Epoch 11/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - accuracy: 0.8438 - loss: 0.4292 - val_accuracy: 0.7391 - val_loss: 0.5925
# Epoch 12/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8438 - loss: 0.4164 - val_accuracy: 0.6774 - val_loss: 0.6927
# Epoch 13/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.8425 - loss: 0.4104 - val_accuracy: 0.7703 - val_loss: 0.6185
# Epoch 14/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 199us/step - accuracy: 0.9688 - loss: 0.2262 - val_accuracy: 0.9677 - val_loss: 0.0954
# Epoch 15/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 219ms/step - accuracy: 0.8626 - loss: 0.3538 - val_accuracy: 0.8188 - val_loss: 0.6022
# Epoch 16/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 258us/step - accuracy: 0.8438 - loss: 0.4300 - val_accuracy: 0.8387 - val_loss: 0.3893
# Epoch 17/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 215ms/step - accuracy: 0.8772 - loss: 0.3258 - val_accuracy: 0.8867 - val_loss: 0.2956
# Epoch 18/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9688 - loss: 0.2005 - val_accuracy: 0.9355 - val_loss: 0.1337
# Epoch 19/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.8801 - loss: 0.3280 - val_accuracy: 0.7711 - val_loss: 0.6322
# Epoch 20/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9375 - loss: 0.1921 - val_accuracy: 0.8710 - val_loss: 0.4731
# Epoch 21/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 216ms/step - accuracy: 0.8903 - loss: 0.3077 - val_accuracy: 0.8875 - val_loss: 0.3031
# Epoch 22/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9375 - loss: 0.1425 - val_accuracy: 1.0000 - val_loss: 0.0330
# Epoch 23/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 216ms/step - accuracy: 0.8987 - loss: 0.2784 - val_accuracy: 0.8266 - val_loss: 0.5076
# Epoch 24/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 226us/step - accuracy: 0.8750 - loss: 0.2544 - val_accuracy: 0.9677 - val_loss: 0.1471
# Epoch 25/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 217ms/step - accuracy: 0.9131 - loss: 0.2345 - val_accuracy: 0.8906 - val_loss: 0.3163
# Epoch 26/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 243us/step - accuracy: 0.9062 - loss: 0.1365 - val_accuracy: 0.9677 - val_loss: 0.0562
# Epoch 27/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 216ms/step - accuracy: 0.9096 - loss: 0.2307 - val_accuracy: 0.9219 - val_loss: 0.2270
# Epoch 28/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9062 - loss: 0.2237 - val_accuracy: 0.9677 - val_loss: 0.0669
# Epoch 29/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - accuracy: 0.9229 - loss: 0.2181 - val_accuracy: 0.8883 - val_loss: 0.3353
# Epoch 30/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8438 - loss: 0.2822 - val_accuracy: 0.9677 - val_loss: 0.1165
# Epoch 31/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 216ms/step - accuracy: 0.9279 - loss: 0.1922 - val_accuracy: 0.9039 - val_loss: 0.2784
# Epoch 32/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8438 - loss: 0.2754 - val_accuracy: 0.9355 - val_loss: 0.2305
# Epoch 33/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 215ms/step - accuracy: 0.9261 - loss: 0.2029 - val_accuracy: 0.9297 - val_loss: 0.1881
# Epoch 34/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 221us/step - accuracy: 0.9375 - loss: 0.1327 - val_accuracy: 0.9677 - val_loss: 0.1264
# Epoch 35/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 42s 228ms/step - accuracy: 0.9358 - loss: 0.1821 - val_accuracy: 0.9258 - val_loss: 0.2024
# Epoch 36/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9062 - loss: 0.4057 - val_accuracy: 0.9355 - val_loss: 0.1860
# Epoch 37/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - accuracy: 0.9446 - loss: 0.1600 - val_accuracy: 0.9445 - val_loss: 0.1713
# Epoch 38/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 252us/step - accuracy: 0.8750 - loss: 0.1650 - val_accuracy: 0.9355 - val_loss: 0.2456
# Epoch 39/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 219ms/step - accuracy: 0.9377 - loss: 0.1627 - val_accuracy: 0.9289 - val_loss: 0.1946
# Epoch 40/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9375 - loss: 0.2896 - val_accuracy: 0.9355 - val_loss: 0.1664
# Epoch 41/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 80s 215ms/step - accuracy: 0.9393 - loss: 0.1611 - val_accuracy: 0.9430 - val_loss: 0.1941
# Epoch 42/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0635 - val_accuracy: 0.9677 - val_loss: 0.0704
# Epoch 43/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - accuracy: 0.9492 - loss: 0.1397 - val_accuracy: 0.9133 - val_loss: 0.2794
# Epoch 44/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 242us/step - accuracy: 0.8750 - loss: 0.2886 - val_accuracy: 0.9355 - val_loss: 0.1512
# Epoch 45/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 219ms/step - accuracy: 0.9379 - loss: 0.1563 - val_accuracy: 0.9219 - val_loss: 0.2023
# Epoch 46/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9688 - loss: 0.0719 - val_accuracy: 0.9355 - val_loss: 0.1712
# Epoch 47/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - accuracy: 0.9546 - loss: 0.1227 - val_accuracy: 0.8992 - val_loss: 0.3235
# Epoch 48/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.9375 - loss: 0.1853 - val_accuracy: 0.9032 - val_loss: 0.2575
# Epoch 49/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 40s 213ms/step - accuracy: 0.9533 - loss: 0.1327 - val_accuracy: 0.9414 - val_loss: 0.1720
# Epoch 50/50
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.9355 - val_loss: 0.1977

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
loss, accuracy = model.evaluate(test_generator, steps=test_generator.samples // batch_size)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9224 - loss: 0.1957
# Test Loss: 0.15500497817993164
# Test Accuracy: 0.942187488079071

# %%
predictions = model.predict(test_generator)
predicted_categories = np.argmax(predictions, axis=1)
true_categories = test_generator.classes

# Create a confusion matrix
confusion_matrix = tf.math.confusion_matrix(true_categories, predicted_categories)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.xticks(ticks=np.arange(len(categories)), labels=categories)
plt.yticks(ticks=np.arange(len(categories)), labels=categories)
plt.show()

# Plot sample images with their predicted and true labels
test_images = test_generator.filenames
sample_indices = np.random.choice(range(len(test_images)), size=9, replace=False)
sample_images = [test_images[i] for i in sample_indices]
sample_predictions = [categories[predicted_categories[i]] for i in sample_indices]
sample_true_labels = [categories[true_categories[i]] for i in sample_indices]

plt.figure(figsize=(12, 8))
for i in range(9):
    plt.subplot(3, 3, i+1)
    img = plt.imread(os.path.join(test_dir, sample_images[i]))
    plt.imshow(img)
    plt.title(f"Predicted: {sample_predictions[i]}\nTrue: {sample_true_labels[i]}")
    plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step

# %%
# Out:
# Class: glioma
# Precision: 0.971830985915493
# Recall: 0.92
# F1-Score: 0.9452054794520549
#
# Class: meningioma
# Precision: 0.9125874125874126
# Recall: 0.8529411764705882
# F1-Score: 0.8817567567567567
#
# Class: notumor
# Precision: 0.9204545454545454
# Recall: 1.0
# F1-Score: 0.9585798816568047
#
# Class: pituitary
# Precision: 0.973421926910299
# Recall: 0.9766666666666667
# F1-Score: 0.9750415973377703

# %%
model.save('my_model.keras')
